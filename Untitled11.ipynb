# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhila1810/ML-ASS-03-2019/blob/master/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1d8mowg85_7P6SJY8bw35jIHjEb7dJvCT)
#
# ![alt text](https://drive.google.com/uc?id=1ZxOhXhxdyIAA0KFmon92RyuuSDIQx0Nv)
#
# PROJECT TITLE
#
#
# “PITCH AND PLAN FOR THE ENHANCEMENT OF IPAD SALES”
#
# https://www.youtube.com/watch?v=s4XTcbfFsK8
#
# AIM
#
#
# Target of this project ------- Improve the sales of iPad similar to the sales of iPhone
#
# Steps to achieve the target ------ Data History and the Sentiment Analysis
#
# Final results of the project ------ Enhancement of the sales
#
# The main aim of this project is to analyse and predict the sale of an Apple product i.e. iPad. Apple has produced several products such as iPad's, iPhone's, smartwatch, smart TV, Desktop, Mac Books, iPod etc. Among these, this brand experiences its maximum productivity and sales from the Mac Books and iPhone's. Later comes the iPad. Even though most of its features are similar to the iPhone, it doesn't expect more sales by this product. The only difference between the iPad and iPhone is the insertion of sim option. So, through this project, we analyse the sales of iPhone and iPad and then aim to enhance the sales of the iPad's similar to the sales of the iPhone. This can be achieved through the research of past sales record. The vital objective of this project is to minimize or reduce the financial capital to the Apple. By reviewing this product, financial losses can be eliminated and thus benefit the company by huge returns of the sales, increase its brand name in the business market, have a strong likeliness in the society for the future launch of new products. All these can be achieved through the process of sentiment analysis on the tweets by the public. By this sentiment analysis, the sentiments of the public i.e. the tweets are classified into positive, negative and neutral. All the tweets are extracted with the hashtag "#iPad" and "#iPhone".
#
# By this sentiment analysis, the sentiments of the public i.e. the tweets are classified into positive, negative and neutral. All the tweets are extracted with the hashtag "#iPad" and "#iPhone". Some of the crucial objectives have been considered to reach the main aim of the project.
#
# ![alt text](https://drive.google.com/uc?id=1Ki9EyJg6cZ-aCuPneEG9ulBGOOlNOEy-)
# Figure 1Various Generations of iPad by the Apple
#
# OBJECTIVES
#
# The main objective of this project is to develop a methodology through the company will be able to predict the future sales of a product and thus contribute to increase its productivity, capital. So, in order to achieve our aim i.e. to improve the sales of iPad's when compared with iPhone's sales, I have considered an approach of sentiment analysis. For this approach, I have collected the data from twitter i.e. the tweets of the public and classify them into positive, negative and neutral words based on the dictionary words. Through this analysis, our key objective to develop a methodology which predicts the outcomes of the iPad sales, thus creating a positive environment in the company as well. For best understanding, I have classified with aim into three important objectives for this project.
#
# They are
#
# ![alt text](https://drive.google.com/uc?id=1Tkf4WDvflToMcyhZVyJGwX-2ZycKCQY_)
# Figure 2Three key objectives of the project
#
#
# BACKGROUND
#
# The brand Apple was founded by the "Steve Jobs" in the year 1964, which is one of the top technological companies in the world. Apple has produced several products such as iPad's, iPhone's, smartwatch, smart TV, Desktop, Mac Books, iPod etc. Among these, this brand experiences its maximum productivity and sales from the Mac Books and iPhone's. Later comes the iPad. Even though most of its features are similar to the iPhone, it doesn't expect more sales by this product. If we examine the data, we can see the downfall of sales from the year 2014. This was a typical moment for the company as they experienced the death of their CEO and the founder as well as the downfall of the sales. So, in order to retain their brand name back, they have searched for the new markets. Through this project, I tried to understand how Apple tried to meet their brand demand and also manage the business industry (Apple Computer Inc., 2006).
#
# The company has to face the downfall of sales from 25 million units to 11 million units. The reason under this downfall of the sales needs to be identified by an approach called twitter sentiment analysis. As we all know how powerful social media platforms these days are. So, I have considered the social media platform i.e. twitter for my project. Using this, I will collect the tweets of the public and classify them into the dictionary, which are described in the later parts of the project report.
#
# ![alt text](https://drive.google.com/uc?id=1hLXHg1_gA1aqHyiekrDXoVsyaHx44iYX)
# Figure 3“Global Apple iPad sales from 3rd quarter 2010 to 3rd quarter 2018 (in million units)" (Statista, 2018)
#
#
# The above figure 3 explains to us about the iPad sales between the timeline of quarter 3rd of 2010 to quarter 3rd of 2018. From this graph, we can observe the rise and downfall of the sales from 2010 to 2018 and 2012 to 2016 respectively. From the past three quarters, 33.83 million iPads were sold by Apple in the whole world. When compared to the sales in the year 2107 this is less. In a single year, 43.75 million iPads were sold.
#
# In 2010, Apple has introduced its first-generation iPad series with a touch screen and a virtual keyboard. iPhones are the new growth of technology in the smartphone market. From the first-generation to till date there are six versions of iPad's which runs with the platform of iOS. iOS was also developed by Apple and stands as the world's second-best popular operating system. Since the year 2010, a drastic number of iPads i.e. about 350 million iPads were sold globally. Apple has increased its market share to 15 per cent by the end of the year 2017 (Apple, 2018). By launching iPad air in the year 2013, November the sales of these iPads were more than 26 million times than the sales of iPads from the year 2013. These sales were highest until 2014.
#
# But from the past few years, we can observe the downfall of the sales. So, by this project, our target is to bring back the sales of iPads as in the year 2013 and must be similar and competitive to the sales of iPhones.
#
# SOLUTION
#
# But from the past few years, we can observe the downfall of the sales. The reason under this downfall of the sales needs to be identified by an approach called twitter sentiment analysis. As we all know how powerful social media platforms these days are. So, I have considered the social media platform i.e. twitter for my project. Using this, I will extract the tweets of the public. By these tweets, we can understand the user concerns and feeling more clearer and try to implement them in the future versions of the iPad. So, our target is to bring back the sales of iPads as in the year 2013 and must be similar and competitive to the sales of iPhones.
#
# EXISTING APPROACH
#
# The existing approach that Apple follows is the "Judgmental approach". In this approach, the organization set-ups an end goal in the process of estimating the demand. In this process, people suggest their opinions to achieve the final target (Apple Computer Inc., 2006). Using this methodology great innovations were made which helped the brand to be the top in the business world market.
#
# ASSOCIATION WITH THE PROPOSED PROJECT
#
# These methodologies were discovered with the specific goal to achieve business problems. Through this process, the customer details and preferences are collected and then examined individually for the specific outcome. They also consider the past sales record for this. The crucial customers for this kind of analysis are the customers of other organisations such as HP, Samsung, Dell etc. The only reason for considering these companies is as they are in manufacturing history from the past years and have good knowledge about the customer needs in laptops, tablets etc.
#
# RESEARCH PROJECT
#
# In this section, I will discuss the various parts that are responsible for the incrementation of sales of iPads.
#
# SIGNIFICANCE OF THE PROJECT
#
# This project aims to improve the capital of Apple by increasing its sales of iPads. In order to achieve, we use the data analytics techniques in each we use the existing data of the sales and then predict the data of the sales in future. This type of analysis will have a great significance for the company as they deal with real-time data.
#
# INNOVATION
#
# The most innovative part of this project, the prediction procedure by the sentiment analysis. Sentiment analysis is a method in which we understand the feeling of the public and use them to improvise the products. For this project, I have decided to use the twitter social media platform. As well know how powerful social media platforms these days are. So, I have considered the social media platform i.e. twitter for my project. Using this, I will collect the tweets of the public and classify them into the dictionary, which is described in the later parts of the project report. Our target is to bring back the sales of iPads as in the year 2013 and must be similar and competitive to the sales of iPhones. We also analyse the various strategies like the best time and situations for releasing the new products etc.
#
# METHODOLOGY FOR SOLVING THE PROBLEM
#
# For the successful implementation of this project, I planned to use the R programming language. To this, we execute programming in RStudio. The initial step is to extract the tweets from twitter by using the hashtag #iPad. As soon as we finish this extraction, the second next step is to clean the dataset i.e. to the elimination of stop words, URL's, numbers and punctuations. After this step, the data is analysed by applying various classifiers such as K-NN, Naive-Bayes. All this classification will be executed in a tool called Orange.
#
# ![alt text](https://drive.google.com/uc?id=10mUkHYDouLsdCar4Jney96E-bFmFZvJu)
# Figure 4Workflow Process in Orange
#
# The first step is to build the training set. This has both the positive and negative words which are considered as 1 and 0 respectively. As soon as the training set is built in the Orange, we can use it as the testing dataset. Through this dataset, we analyse our predictions. Next step is to analyse the sentiments of the tweets which can then we validated in a ratio. If the negative words are more i.e. if the ratio is high, then we need to analyse the product based on the comments so that we can increase our sales in the future products. Word count is used to pairing the frequently used words with the hashtag. This is also done in RStudio.
#
# ![alt text](https://drive.google.com/uc?id=16aod40_MHrY4i4_xcX0EdbxIa1ND9c9g)
# Figure 5Polarity of positive and negative words
#
# ![alt text](https://drive.google.com/uc?id=1rsbMGjX1TCSzufJ0fGmihJ7kkPrIKk3X)
# Figure 6 Sentiment analysis using Bar Graph
#
# The above results are used in analysing the highest and lowest sales of iPads.
#
# GANTT CHART
#
# Using the Gantt Chart, we can determine the time and the task estimation of the project. Appendix A represents this.
#
# OUTCOMES AND BENEFITS
#
# Soon after the analysation, we need to construct the model which is used as the predicted sales. This prediction helps the company to attain maximum profits. The main aim of this project is to determine the reason for the sudden downfall of sales in the year 2014. this can be identified by the sentiment analysis through keywords. So, after identifying the reason, we need to fix them. We analysed all this in a scientific research approach and then predicted the future sales of the company. through the process of identifying the faults, we can improve the sales of the products and thus contribute to the enhancements of the brand name in the market.
#
# BUDGET
#
# This part involves the budget allocation to the investor. This allocation will be divided into three main parts.
#
# They are
#
# 1. Personal
# 2. Software
# 3. Hardware
#
# ![alt text](https://drive.google.com/uc?id=1a_rrNH5XEGiGf4jgKfXM3I5bZndRxT2f)
# Table 7 Budget Allocation
#
# PERSONNEL
#
# The success of a project is teamwork and it will depend on every individual of the team. The project team consists of
# 1. Project manager – He/she will play a key role in the project. They take initiative from first to the end of the project.
# 2. Research assistant – He/she plays a key role in initiating the project. He is responsible for all the initial research work
# 3. Data Analyst – Research assistant will assign all the tasks to the data analyst.
# 4. Developer – Deployment of the data will be done by the developer.
# 5. Marketing specialist – He/she is responsible for the application of various strategies by which the customers are attracted.
#
# REFERENCES
#
# ![alt text](https://drive.google.com/uc?id=134KRgOYdwR2kjAJka-Ei5gi9cCOAapWo)
#
# TABLE OF FIGURES
#
# ![alt text](https://drive.google.com/uc?id=1JFoQiJIVqqJMA3uBS3ma4RfWysTWajKT)
#
#
# APPENDIX
#
# ![alt text](https://drive.google.com/uc?id=1ds9zpsvqNy7xAYyQtvu9lPku7dp2nR5J)
#
# ![alt text](https://drive.google.com/uc?id=1fknZ_EIxZjZDycfEdy4vQS_drlb-7bYt)
#
# ![alt text](https://drive.google.com/uc?id=1KHNVwUs3Qci4fraRid6vDveUGOpzoHSn)
